# %%
import numpy as np
import pandas as pd

# %%
dict1={'name':['surbhi','isha','sam','zainab'],
      'city':['mathura','noida','pnp','bareilly'],
      'marks':['80','85','70','69']}

# %%
df=pd.DataFrame(dict1)

# %%
df
# Out:
#      name      city marks
# 0  surbhi   mathura    80
# 1    isha     noida    85
# 2     sam       pnp    70
# 3  zainab  bareilly    69

# %%
df.to_csv('friends.csv')

# %%
df.to_csv('friends_no_index.csv',index=False)

# %%
df.head(2)
# Out:
#      name     city marks
# 0  surbhi  mathura    80
# 1    isha    noida    85

# %%
df.tail(2)
# Out:
#      name      city marks
# 2     sam       pnp    70
# 3  zainab  bareilly    69

# %%
df.describe()
# Out:
#           name     city marks
# count        4        4     4
# unique       4        4     4
# top     surbhi  mathura    80
# freq         1        1     1

# %%
surbhi=pd.read_csv('friends.csv')

# %%
surbhi
# Out:
#    Unnamed: 0    name      city  marks
# 0           0  surbhi   mathura     80
# 1           1    isha     noida     85
# 2           2     sam       pnp     70
# 3           3  zainab  bareilly     69

# %%
surbhi['city'][0]
# Out:
# 'mathura'

# %%
surbhi['city'][2]='bareilly'
# Out:
# C:\Users\Surbhi\AppData\Local\Temp\ipykernel_6504\200394999.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   surbhi['city'][2]='bareilly'

# %%
surbhi
# Out:
#    Unnamed: 0    name      city  marks
# 0           0  surbhi   mathura     80
# 1           1    isha     noida     85
# 2           2     sam  bareilly     70
# 3           3  zainab  bareilly     69

# %%
surbhi.to_csv('friends_edit.csv')

# %%
surbhi.index=['first','second','Third','fourth']

# %%
surbhi
# Out:
#         Unnamed: 0    name      city  marks
# first            0  surbhi   mathura     80
# second           1    isha     noida     85
# Third            2     sam  bareilly     70
# fourth           3  zainab  bareilly     69

# %%
ser=pd.Series(np.random.rand(34))

# %%
ser
# Out:
# 0     0.213723
# 1     0.870870
# 2     0.958787
# 3     0.485197
# 4     0.224816
# 5     0.370986
# 6     0.284270
# 7     0.243944
# 8     0.191026
# 9     0.682729
# 10    0.307894
# 11    0.891221
# 12    0.377668
# 13    0.919023
# 14    0.126661
# 15    0.341027
# 16    0.451362
# 17    0.842809
# 18    0.055029
# 19    0.511460
# 20    0.215348
# 21    0.502088
# 22    0.957185
# 23    0.833960
# 24    0.782222
# 25    0.996996
# 26    0.762062
# 27    0.373963
# 28    0.666862
# 29    0.883766
# 30    0.990025
# 31    0.057660
# 32    0.361038
# 33    0.263023
# dtype: float64

# %%
type(ser)
# Out:
# pandas.core.series.Series

# %%
newdf=pd.DataFrame(np.random.rand(334,5),index=np.arange(334))

# %%
newdf
# Out:
#             0         1         2         3         4
# 0    0.787606  0.661368  0.455691  0.002060  0.934583
# 1    0.806956  0.265352  0.111291  0.921135  0.247772
# 2    0.133546  0.857498  0.468611  0.390326  0.024695
# 3    0.340141  0.485533  0.249676  0.664694  0.604170
# 4    0.755252  0.712419  0.683896  0.811077  0.300173
# ..        ...       ...       ...       ...       ...
# 329  0.164012  0.705619  0.208784  0.123708  0.700373
# 330  0.861809  0.256481  0.778608  0.482450  0.912000
# 331  0.328760  0.729983  0.320607  0.429095  0.867203
# 332  0.605751  0.171721  0.483037  0.145656  0.140888
# 333  0.021476  0.969566  0.789361  0.771752  0.033259
#
# [334 rows x 5 columns]

# %%
type(newdf)
# Out:
# pandas.core.frame.DataFrame

# %%
newdf.describe()
# Out:
#                 0           1           2           3           4
# count  334.000000  334.000000  334.000000  334.000000  334.000000
# mean     0
# %%
newdf.head(4)
# Out:
#           A         B         C         D         E
# 0       654  0.661368  0.455691  0.002060  0.934583
# 1  0.806956  0.265352  0.111291  0.921135  0.247772
# 2  0.133546  0.857498  0.468611  0.390326  0.024695
# 3  0.340141  0.485533  0.249676  0.664694  0.604170

# %%
newdf.drop(['A'],axis=1,inplace=True)

# %%
newdf.head(4)
# Out:
#           B         C         D         E
# 0  0.661368  0.455691  0.002060  0.934583
# 1  0.265352  0.111291  0.921135  0.247772
# 2  0.857498  0.468611  0.390326  0.024695
# 3  0.485533  0.249676  0.664694  0.604170

# %%
 newdf.drop([1,5],inplace=True)

# %%
newdf
# Out:
#             B         C         D         E
# 0    0.661368  0.455691  0.002060  0.934583
# 2    0.857498  0.468611  0.390326  0.024695
# 3    0.485533  0.249676  0.664694  0.604170
# 4    0.712419  0.683896  0.811077  0.300173
# 6    0.840238  0.006541  0.819356  0.018615
# ..        ...       ...       ...       ...
# 329  0.705619  0.208784  0.123708  0.700373
# 330  0.256481  0.778608  0.482450  0.912000
# 331  0.729983  0.320607  0.429095  0.867203
# 332  0.171721  0.483037  0.145656  0.140888
# 333  0.969566  0.789361  0.771752  0.033259
#
# [332 rows x 4 columns]

# %%
newdf.reset_index()
# Out:
#      index         B         C         D         E
# 0        0  0.661368  0.455691  0.002060  0.934583
# 1        2  0.857498  0.468611  0.390326  0.024695
# 2        3  0.485533  0.249676  0.664694  0.604170
# 3        4  0.712419  0.683896  0.811077  0.300173
# 4        6  0.840238  0.006541  0.819356  0.018615
# ..     ...       ...       ...       ...       ...
# 327    329  0.705619  0.208784  0.123708  0.700373
# 328    330  0.256481  0.778608  0.482450  0.912000
# 329    331  0.729983  0.320607  0.429095  0.867203
# 330    332  0.171721  0.483037  0.145656  0.140888
# 331    333  0.969566  0.789361  0.771752  0.033259
#
# [332 rows x 5 columns]

# %%
newdf.reset_index(drop=True,inplace=True)

# %%
newdf
# Out:
#             B         C         D         E
# 0    0.661368  0.455691  0.002060  0.934583
# 1    0.857498  0.468611  0.390326  0.024695
# 2    0.485533  0.249676  0.664694  0.604170
# 3    0.712419  0.683896  0.811077  0.300173
# 4    0.840238  0.006541  0.819356  0.018615
# ..        ...       ...       ...       ...
# 327  0.705619  0.208784  0.123708  0.700373
# 328  0.256481  0.778608  0.482450  0.912000
# 329  0.729983  0.320607  0.429095  0.867203
# 330  0.171721  0.483037  0.145656  0.140888
# 331  0.969566  0.789361  0.771752  0.033259
#
# [332 rows x 4 columns]

# %%
newdf['B'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 327    False
# 328    False
# 329    False
# 330    False
# 331    False
# Name: B, Length: 332, dtype: bool

# %%
newdf.loc[:,['B']]=None

# %%
newdf.head(5)
# Out:
#       B         C         D         E
# 0  None  0.455691  0.002060  0.934583
# 1  None  0.468611  0.390326  0.024695
# 2  None  0.249676  0.664694  0.604170
# 3  None  0.683896  0.811077  0.300173
# 4  None  0.006541  0.819356  0.018615

# %%
newdf[['B']].isnull()
# Out:
#         B
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# ..    ...
# 327  True
# 328  True
# 329  True
# 330  True
# 331  True
#
# [332 rows x 1 columns]

# %%
df=pd.DataFrame({"name":['ashhS','WS','ashhS'],
                "toy":[np.nan,np.nan,np.nan],
                "born":[pd.NaT,pd.Timestamp('1980-01-13'),pd.NaT]})

# %%
df
# Out:
#     name  toy       born
# 0  ashhS  NaN        NaT
# 1     WS  NaN 1980-01-13
# 2  ashhS  NaN        NaT

# %%
df.dropna()
# Out:
# Empty DataFrame
# Columns: [name, toy, born]
# Index: []

# %%
df.dropna(how='all',axis=1)
# Out:
#     name       born
# 0  ashhS        NaT
# 1     WS 1980-01-13
# 2  ashhS        NaT

# %%
df.drop_duplicates(subset=['name'])
# Out:
#     name  toy       born
# 0  ashhS  NaN        NaT
# 1     WS  NaN 1980-01-13

# %%
df.drop_duplicates(subset=['name'],keep=False)
# Out:
#   name  toy       born
# 1   WS  NaN 1980-01-13

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    3 non-null      object
#  1   toy     0 non-null      float64
#  2   born    1 non-null      datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 200.0+ bytes

# %%
df['name'].value_counts(dropna=True)
# Out:
# ashhS    2
# WS       1
# Name: name, dtype: int64

# %%
df['toy'].value_counts(dropna=False)
# Out:
# NaN    3
# Name: toy, dtype: int64

# %%
newdf_2=pd.DataFrame(np.random.rand(3,2))

# %%
newdf_2
# Out:
#           0         1
# 0  0.495429  0.968669
# 1  0.198093  0.170241
# 2  0.039269  0.914160

# %%
newdf_2.describe()
# Out:
#               0         1
# count  3.000000  3.000000
# mean   0.244264  0.684357
# std    0.231558  0.446071
# min    0.039269  0.170241
# 25%    0.118681  0.542201
# 50%    0.198093  0.914160
# 75%    0.346761  0.941415
# max    0.495429  0.968669

# %%
newdf_2.mean()
# Out:
# 0    0.244264
# 1    0.684357
# dtype: float64

# %%
newdf_2.corr()
# Out:
#           0         1
# 0  1.000000  0.232538
# 1  0.232538  1.000000

# %%
newdf_2.count()
# Out:
# 0    3
# 1    3
# dtype: int64

# %%
newdf_2.max()
# Out:
# 0    0.495429
# 1    0.968669
# dtype: float64

# %%
newdf_2.min()
# Out:
# 0    0.039269
# 1    0.170241
# dtype: float64

# %%
newdf_2.median()
# Out:
# 0    0.198093
# 1    0.914160
# dtype: float64

# %%
newdf_2.std()
# Out:
# 0    0.231558
# 1    0.446071
# dtype: float64

# %%
data=pd.read_excel('datacloud.xlsx')

# %%
data
# Out:
#     Unnamed: 0      Track 2: Cloud-native Application Development  \
# 0            0                                                NaN
# 1            1                                                NaN
# 2            2                                         Quest Name
# 3            3                        Google Developer Essentials
# 4            4  OK Google: Build Interactive Apps with Google ...
# 5            5                                  Cloud Development
# 6            6                            Website on Google Cloud
# 7            7                     Baseline: Deploy &amp; Develop
# 8            8                                     Exploring APIs
# 9            9                            IoT in the Google Cloud
# 10          10                                 Workspace: Add-ons
# 11          11            Build Apps &amp; Websites with Firebase
# 12          12               Google Cloud Run Serverless Workshop
#
# ...

# %%
data=pd.read_excel('datacloud.xlsx',sheet_name='Track 2')

# %%
data
# Out:
#     Unnamed: 0      Track 2: Cloud-native Application Development  \
# 0            0                                                NaN
# 1            1                                                NaN
# 2            2                                         Quest Name
# 3            3                        Google Developer Essentials
# 4            4  OK Google: Build Interactive Apps with Google ...
# 5            5                                  Cloud Development
# 6            6                            Website on Google Cloud
# 7            7                     Baseline: Deploy &amp; Develop
# 8            8                                     Exploring APIs
# 9            9                            IoT in the Google Cloud
# 10          10                                 Workspace: Add-ons
# 11          11            Build Apps &amp; Websites with Firebase
# 12          12               Google Cloud Run Serverless Workshop
#
# ...

# %%
data.to_excel('datacloud.xlsx',sheet_name='Track 2')

# %%
data
# Out:
#     Unnamed: 0      Track 2: Cloud-native Application Development  \
# 0            0                                                NaN
# 1            1                                                NaN
# 2            2                                         Quest Name
# 3            3                        Google Developer Essentials
# 4            4  OK Google: Build Interactive Apps with Google ...
# 5            5                                  Cloud Development
# 6            6                            Website on Google Cloud
# 7            7                     Baseline: Deploy &amp; Develop
# 8            8                                     Exploring APIs
# 9            9                            IoT in the Google Cloud
# 10          10                                 Workspace: Add-ons
# 11          11            Build Apps &amp; Websites with Firebase
# 12          12               Google Cloud Run Serverless Workshop
#
# ...
